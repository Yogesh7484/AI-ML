# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

# %%
df = pd.read_csv('/content/Bank_Customerdata.csv')

print(df.head())
# Out:
#    ID  Age  Experience  Income  Zipcode  Family    CCAvg  Education  Mortgage  \
# 0   1   39          14  127000    49560       1   567.28          2     36000
# 1   2   36           0   72000    63865       1  3927.17          1    341000
# 2   3   37           5  147000    56686       2   369.79          1    326000
# 3   4   55           4  199000    85910       4  3847.52          3    406000
# 4   5   45          17  177000    14675       1    26.63          2    424000
#
#    Securities Account  CD Account  Online  CreditCard  Personal Loan
# 0                   1           0       1           0              1
# 1                   1           0       0           0              0
# 2                   0           0       0           1              0
# 3                   0           0       0           0              0
# 4                   0           0       0           0              0

# %%
# Drop unnecessary columns
df.drop(columns=['ID', 'Zipcode'], inplace=True)

# Define target variable (y) and features (X)
y = df['Personal Loan']
X = df.drop(columns=['Personal Loan'])

# Encode categorical variable (Education)
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_edu = pd.DataFrame(encoder.fit_transform(df[['Education']]), columns=encoder.get_feature_names_out(['Education']))

# Drop original 'Education' column and add encoded values
X = X.drop(columns=['Education'])
X = pd.concat([X, encoded_edu], axis=1)

# %%
# Scale numerical features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Split data into training & testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"Training Data Shape: {X_train.shape}, Test Data Shape: {X_test.shape}")
# Out:
# Training Data Shape: (400, 12), Test Data Shape: (100, 12)

# %%
# Define the model

model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model

test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8102 - loss: 0.5980 - val_accuracy: 0.8400 - val_loss: 0.5366
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8724 - loss: 0.4699 - val_accuracy: 0.8400 - val_loss: 0.4811
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8584 - loss: 0.4188 - val_accuracy: 0.8400 - val_loss: 0.4673
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8403 - loss: 0.4353 - val_accuracy: 0.8400 - val_loss: 0.4635
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8314 - loss: 0.4309 - val_accuracy: 0.8400 - val_loss: 0.4595
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8441 - loss: 0.4040 - val_accuracy: 0.8400 - val_loss: 0.4575
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8427 - loss: 0.3975 - val_accuracy: 0.8400 - val_loss: 0.4549
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8492 - loss: 0.3824 - val_accuracy: 0.8400 - val_loss: 0.4564
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8614 - loss: 0.3617 - val_accuracy: 0.8300 - val_loss: 0.4528
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.3684 - val_accuracy: 0.8200 - val_loss: 0.4533
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8083 - loss: 0.4381 - val_accuracy: 0.8200 - val_loss: 0.4511
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8640 - loss: 0.3618 - val_accuracy: 0.8300 - val_loss: 0.4539
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8278 - loss: 0.4042 - val_accuracy: 0.8200 - val_loss: 0.4521
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8503 - loss: 0.3705 - val_accuracy: 0.8200 - val_loss: 0.4558
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8733 - loss: 0.3181 - val_accuracy: 0.8200 - val_loss: 0.4524
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8789 - loss: 0.3143 - val_accuracy: 0.8200 - val_loss: 0.4552
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8944 - loss: 0.2921 - val_accuracy: 0.8200 - val_loss: 0.4550
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8673 - loss: 0.3278 - val_accuracy: 0.8200 - val_loss: 0.4524
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8835 - loss: 0.2939 - val_accuracy: 0.8200 - val_loss: 0.4571
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8755 - loss: 0.3151 - val_accuracy: 0.8100 - val_loss: 0.4606
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8749 - loss: 0.3067 - val_accuracy: 0.8100 - val_loss: 0.4571
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8893 - loss: 0.2889 - val_accuracy: 0.8100 - val_loss: 0.4617
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8741 - loss: 0.2809 - val_accuracy: 0.8100 - val_loss: 0.4670
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8886 - loss: 0.2681 - val_accuracy: 0.8100 - val_loss: 0.4707
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8824 - loss: 0.2779 - val_accuracy: 0.8100 - val_loss: 0.4764
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8992 - loss: 0.2399 - val_accuracy: 0.8100 - val_loss: 0.4793
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8803 - loss: 0.2745 - val_accuracy: 0.8100 - val_loss: 0.4834
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8870 - loss: 0.2538 - val_accuracy: 0.8100 - val_loss: 0.4939
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8818 - loss: 0.2563 - val_accuracy: 0.8100 - val_loss: 0.4990
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8752 - loss: 0.2771 - val_accuracy: 0.8300 - val_loss: 0.5033
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8782 - loss: 0.2633 - val_accuracy: 0.8100 - val_loss: 0.5016
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9040 - loss: 0.2150 - val_accuracy: 0.8200 - val_loss: 0.5149
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8962 - loss: 0.2380 - val_accuracy: 0.8200 - val_loss: 0.5038
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9025 - loss: 0.2125 - val_accuracy: 0.8300 - val_loss: 0.5223
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9117 - loss: 0.1978 - val_accuracy: 0.8200 - val_loss: 0.5216
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9273 - loss: 0.1673 - val_accuracy: 0.8300 - val_loss: 0.5267
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9033 - loss: 0.2045 - val_accuracy: 0.8400 - val_loss: 0.5306
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9061 - loss: 0.1989 - val_accuracy: 0.8400 - val_loss: 0.5374
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9079 - loss: 0.1977 - val_accuracy: 0.8300 - val_loss: 0.5487
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9053 - loss: 0.2004 - val_accuracy: 0.8100 - val_loss: 0.5674
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9250 - loss: 0.1602 - val_accuracy: 0.8200 - val_loss: 0.5837
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9281 - loss: 0.1707 - val_accuracy: 0.8100 - val_loss: 0.5751
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9336 - loss: 0.1473 - val_accuracy: 0.8200 - val_loss: 0.6032
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9374 - loss: 0.1389 - val_accuracy: 0.8100 - val_loss: 0.6129
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9576 - loss: 0.1245 - val_accuracy: 0.8100 - val_loss: 0.6228
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9538 - loss: 0.1429 - val_accuracy: 0.8000 - val_loss: 0.6365
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9387 - loss: 0.1376 - val_accuracy: 0.8000 - val_loss: 0.6593
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9645 - loss: 0.1220 - val_accuracy: 0.8000 - val_loss: 0.6624
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9648 - loss: 0.1016 - val_accuracy: 0.7900 - val_loss: 0.6818
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9607 - loss: 0.1125 - val_accuracy: 0.8000 - val_loss: 0.6968
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8117 - loss: 0.6727
# Test Accuracy: 0.80
