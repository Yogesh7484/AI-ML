# %%
from IPython import get_ipython
from IPython.display import display

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/Bank_Customerdata.csv')

print(df.head())
# Out:
#    ID  Age  Experience  Income  Zipcode  Family    CCAvg  Education  Mortgage  \
# 0   1   39          14  127000    49560       1   567.28          2     36000
# 1   2   36           0   72000    63865       1  3927.17          1    341000
# 2   3   37           5  147000    56686       2   369.79          1    326000
# 3   4   55           4  199000    85910       4  3847.52          3    406000
# 4   5   45          17  177000    14675       1    26.63          2    424000
#
#    Securities Account  CD Account  Online  CreditCard  Personal Loan
# 0                   1           0       1           0              1
# 1                   1           0       0           0              0
# 2                   0           0       0           1              0
# 3                   0           0       0           0              0
# 4                   0           0       0           0              0

# %%
# Check if columns exist before dropping
if 'ID' in df.columns and 'Zipcode' in df.columns:
    df.drop(['ID', 'Zipcode'], axis=1, inplace=True)
else:
    print("Columns 'ID' and/or 'Zipcode' have already been removed.")

# Split into features and target
X = df.drop("Personal Loan", axis=1)
y = df["Personal Loan"]

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Handle class imbalance
sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# Scale features
scaler = StandardScaler()
X_train_res = scaler.fit_transform(X_train_res)
X_test = scaler.transform(X_test)

# %%
# 6. Build the model
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])
# 7. Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 8. Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# 9. Evaluate on test data
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.8182 - loss: 5651.9136 - val_accuracy: 0.8125 - val_loss: 3498.7598
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7512 - loss: 3432.7725 - val_accuracy: 0.8000 - val_loss: 2846.1235
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7833 - loss: 2996.1135 - val_accuracy: 0.8125 - val_loss: 2770.7620
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8136 - loss: 2867.8792 - val_accuracy: 0.7875 - val_loss: 1767.6761
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7553 - loss: 2607.2593 - val_accuracy: 0.7375 - val_loss: 1484.0406
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7304 - loss: 3373.1707 - val_accuracy: 0.8125 - val_loss: 1547.0811
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7033 - loss: 3173.9141 - val_accuracy: 0.8250 - val_loss: 1957.0852
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7708 - loss: 2322.0425 - val_accuracy: 0.8250 - val_loss: 1890.1176
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7074 - loss: 2750.6184 - val_accuracy: 0.8125 - val_loss: 1567.8418
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7601 - loss: 1930.2665 - val_accuracy: 0.8250 - val_loss: 1394.9098
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7786 - loss: 1381.2968 - val_accuracy: 0.8250 - val_loss: 1146.0735
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7091 - loss: 1874.6099 - val_accuracy: 0.8250 - val_loss: 1150.5829
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7952 - loss: 1255.3132 - val_accuracy: 0.8250 - val_loss: 1250.5149
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7879 - loss: 1791.3344 - val_accuracy: 0.8250 - val_loss: 588.2538
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6941 - loss: 1506.0431 - val_accuracy: 0.8250 - val_loss: 1013.4828
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8056 - loss: 1480.6168 - val_accuracy: 0.8250 - val_loss: 750.3944
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7516 - loss: 1638.6243 - val_accuracy: 0.8250 - val_loss: 469.8256
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7249 - loss: 1016.9763 - val_accuracy: 0.8125 - val_loss: 501.8544
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7883 - loss: 599.7266 - val_accuracy: 0.8250 - val_loss: 403.1970
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7160 - loss: 1221.9717 - val_accuracy: 0.8250 - val_loss: 435.5480
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7719 - loss: 776.0764 - val_accuracy: 0.7625 - val_loss: 238.1902
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7339 - loss: 1024.1777 - val_accuracy: 0.8125 - val_loss: 508.9634
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7918 - loss: 917.4996 - val_accuracy: 0.8000 - val_loss: 333.5069
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7523 - loss: 570.5837 - val_accuracy: 0.8000 - val_loss: 280.7050
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7929 - loss: 498.4449 - val_accuracy: 0.8250 - val_loss: 353.9132
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8100 - loss: 473.5726 - val_accuracy: 0.8250 - val_loss: 353.9484
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7635 - loss: 770.2339 - val_accuracy: 0.8125 - val_loss: 278.4007
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8243 - loss: 395.8298 - val_accuracy: 0.7875 - val_loss: 356.8814
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7285 - loss: 794.6655 - val_accuracy: 0.7500 - val_loss: 211.8607
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7766 - loss: 477.4525 - val_accuracy: 0.8250 - val_loss: 320.3978
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7956 - loss: 649.1818 - val_accuracy: 0.8250 - val_loss: 168.7002
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7548 - loss: 647.1785 - val_accuracy: 0.7750 - val_loss: 161.1639
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7337 - loss: 570.8649 - val_accuracy: 0.6500 - val_loss: 165.8830
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7471 - loss: 565.5774 - val_accuracy: 0.7875 - val_loss: 188.9516
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8245 - loss: 343.1118 - val_accuracy: 0.3875 - val_loss: 420.0241
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6917 - loss: 620.8958 - val_accuracy: 0.7750 - val_loss: 262.1339
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8342 - loss: 468.2520 - val_accuracy: 0.4375 - val_loss: 241.7800
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7104 - loss: 456.3714 - val_accuracy: 0.7875 - val_loss: 210.3733
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8000 - loss: 367.4744 - val_accuracy: 0.6875 - val_loss: 133.5514
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8183 - loss: 353.1659 - val_accuracy: 0.5625 - val_loss: 153.7225
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7087 - loss: 436.9554 - val_accuracy: 0.8125 - val_loss: 176.0428
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7913 - loss: 414.6956 - val_accuracy: 0.7625 - val_loss: 106.9013
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7514 - loss: 391.1878 - val_accuracy: 0.8000 - val_loss: 107.1640
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8389 - loss: 267.2921 - val_accuracy: 0.8125 - val_loss: 123.3433
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7804 - loss: 409.1263 - val_accuracy: 0.8250 - val_loss: 241.4405
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7769 - loss: 406.4735 - val_accuracy: 0.7750 - val_loss: 121.2161
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7247 - loss: 545.0006 - val_accuracy: 0.7375 - val_loss: 106.8422
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8040 - loss: 309.3512 - val_accuracy: 0.5000 - val_loss: 156.5776
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7403 - loss: 372.7524 - val_accuracy: 0.7250 - val_loss: 79.8867
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7122 - loss: 313.6736 - val_accuracy: 0.8375 - val_loss: 115.6585
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Accuracy: 0.55
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.58      0.69        85
#            1       0.14      0.40      0.21        15
#
#     accuracy                           0.55       100
#    macro avg       0.49      0.49      0.45       100
# weighted avg       0.74      0.55      0.61       100
#
#
# Confusion Matrix:
#  [[49 36]
#  [ 9  6]]

# %%
# Create a DataFrame with actual vs predicted labels
df_test_results = pd.DataFrame({"Actual": y_test, "Predicted": y_pred.flatten()})

# Find misclassified cases
misclassified = df_test_results[df_test_results["Actual"] != df_test_results["Predicted"]]
print("Misclassified Samples:\n", misclassified.head())
# Out:
# Misclassified Samples:
#       Actual  Predicted
# 439       0          1
# 490       0          1
# 38        0          1
# 172       1          0
# 175       0          1

# %%
import shap

# Use the trained model 'model' instead of 'best_model'
explainer = shap.Explainer(model, X_test)
shap_values = explainer(X_test)

# Visualize feature importance
shap.summary_plot(shap_values, X_test)
# Out:
# PermutationExplainer explainer: 101it [00:17,  3.13it/s]
# <ipython-input-9-cb6bcc3c284b>:8: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_test)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reduce to 2D using PCA
pca = PCA(n_components=2)
X_test_pca = pca.fit_transform(X_test)

# Scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], c=y_pred.flatten(), cmap="coolwarm", alpha=0.6)
plt.title("Decision Boundary Visualization (PCA Projection)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar(label="Predicted Label")
plt.show()
